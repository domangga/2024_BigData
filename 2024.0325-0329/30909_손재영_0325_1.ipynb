# %% [markdown]
# # 30909_손재영_0325_1

# %%
print('1부터 n까지 정수의 합을 구합니다.')
n=int(input('n갑을 입력하세요'))
while n<=0:   
    n=int(input('n갑을 입력하세요'))

sum=0
i=1
for i in range (1,n+1):
    sum+=i
print(f"1부터 {n}까지 정수의 합은 {sum}입니다.")
# Out:
# 1부터 n까지 정수의 합을 구합니다.
# n갑을 입력하세요10
# 1부터 10까지 정수의 합은 55입니다.

# %%
while True:   
    n=int(input('n갑을 입력하세요'))
    if n > 0:
        break
sum=0
i=1
for i in range(1,n+1):
    sum+=i

print(f"1부터 {n}까지 정수의 합은 {sum}입니다.")
# Out:
# n갑을 입력하세요-1
# n갑을 입력하세요-1
# n갑을 입력하세요0
# n갑을 입력하세요10
# 1부터 10까지 정수의 합은 55입니다.

# %% [markdown]
# - 벼의 길이와 넓이가 모두 정수인 직사각형에서 변의 길이를 구하는 프로그램
# - 짧은 변과 긴 변의 길이는 구별하지 않음
#   - 예)직사각형의 넓이가 32이면 변의 길이를 1x32, 2x16, 4x8만 출력

# %%
# 가로, 세로 길이가 정수이고 넓이가 area인 직사각형에서 변의 길이 나영하기

area=int(input("직사각형의 넓이를 입력하세요.: "))

for i in range(1,area+1):
    if i*i >area : break
    if area % i :continue
    print(f"{i}x{area//i}")
# Out:
# 직사각형의 넓이를 입력하세요.: 100000000000000000
# 1x100000000000000000
# 2x50000000000000000
# 4x25000000000000000
# 5x20000000000000000
# 8x12500000000000000
# 10x10000000000000000
# 16x6250000000000000
# 20x5000000000000000
# 25x4000000000000000
# 32x3125000000000000
# 40x2500000000000000
# 50x2000000000000000
# 64x1562500000000000
# 80x1250000000000000
# 100x1000000000000000
# 125x800000000000000
# 128x781250000000000
# 160x625000000000000
# 200x500000000000000
# 250x400000000000000
# 256x390625000000000
# 320x312500000000000
# 400x250000000000000
# 500x200000000000000
# 512x195312500000000
# 625x160000000000000
# 640x156250000000000
# 800x125000000000000
# 1000x100000000000000
# 1024x97656250000000
# 1250x80000000000000
# 1280x78125000000000
# 1600x62500000000000
# 2000x50000000000000
# 2048x48828125000000
# 2500x40000000000000
# 2560x39062500000000
# 3125x32000000000000
# 3200x31250000000000
# 4000x25000000000000
# 4096x24414062500000
# 5000x20000000000000
# 5120x19531250000000
# ...
